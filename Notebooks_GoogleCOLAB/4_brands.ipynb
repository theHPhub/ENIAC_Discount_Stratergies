# %%
https://drive.google.com/file/d/1skso1hrbzt6PY6O2UpnZR3ZyGtV888B_/view?usp=sharing

# %%
import pandas as pd

# %%
url = 'https://drive.google.com/file/d/1skso1hrbzt6PY6O2UpnZR3ZyGtV888B_/view?usp=sharing'
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
df = pd.read_csv(path)
df
# Out:
#     short       long
# 0     8MO  8Mobility
# 1     ACM       Acme
# 2     ADN     Adonit
# 3     AII      Aiino
# 4     AKI     Akitio
# ..    ...        ...
# 182   XOO     Xoopar
# 183   XRI     X-Rite
# 184   XTO      Xtorm
# 185   ZAG   ZaggKeys
# 186   ZEP       Zepp
#
# [187 rows x 2 columns]

# %%
test_df = df.copy()
test_df
# Out:
#     short       long
# 0     8MO  8Mobility
# 1     ACM       Acme
# 2     ADN     Adonit
# 3     AII      Aiino
# 4     AKI     Akitio
# ..    ...        ...
# 182   XOO     Xoopar
# 183   XRI     X-Rite
# 184   XTO      Xtorm
# 185   ZAG   ZaggKeys
# 186   ZEP       Zepp
#
# [187 rows x 2 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.1+ KB

# %%
test_df.isnull().value_counts()
# Out:
# short  long
# False  False    187
# Name: count, dtype: int64

# %%
test_df.shape
# Out:
# (187, 2)

# %%
test_df['short'].nunique()
# Out:
# 187

# %%
test_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Step 1: Find duplicated brand names in "long"
duplicates = test_df[test_df['long'].duplicated(keep=False)]

# Step 2: Sort by 'long' so duplicates are grouped
duplicates = duplicates.sort_values(by='long')
print(duplicates[['short', 'long']])
# Out:
#     short      long
# 6     AP2     Apple
# 7     APP     Apple
# 17    BOS      Bose
# 19    CAD      Bose
# 67    JYB   Jaybird
# 70    KEN   Jaybird
# 94    MOP    Mophie
# 98    MUJ    Mophie
# 117   OTR  Startech
# 153   STA  Startech
# 37    ENV   Unknown
# 80    LIB   Unknown
