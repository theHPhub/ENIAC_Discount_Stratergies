# %%
https://drive.google.com/file/d/18rWubaeSakTPpPf-RIp8cwBLfNtclbsH/view?usp=sharing

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://drive.google.com/file/d/18rWubaeSakTPpPf-RIp8cwBLfNtclbsH/view?usp=sharing'
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
df = pd.read_csv(path)
df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %%
test_df = df.copy()
test_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %%
test_df.shape
# Out:
# (19326, 7)

# %%
test_df.describe()
# Out:
#            in_stock
# count  19326.000000
# mean       0.109593
# std        0.312390
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
test_df.isnull().sum()
# Out:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %%
test_df.duplicated().sum()
# Out:
# np.int64(8746)

# %% [markdown]
# Removed Duplicate rows:

# %%
df = test_df.drop_duplicates()

# %%
test_df = test_df.drop_duplicates()

# %%
test_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %% [markdown]
# Checking for duplicates in SKU

# %%
test_df.duplicated(subset='sku').sum()
# Out:
# np.int64(1)

# %%
test_df.loc[test_df.duplicated(subset='sku')]
# Out:
#           sku                                               name  \
# 8000  APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display...
#
#                                                    desc price promo_price  \
# 8000  Desktop Apple iMac 21.5 inch i5 31 GHz Retina ...   NaN     1305.59
#
#       in_stock  type
# 8000         0  1282

# %%
test_df = test_df.drop_duplicates(subset='sku')

# %%
test_df.duplicated(subset='sku').sum()
# Out:
# np.int64(0)

# %% [markdown]
# Dropping null values:

# %%
test_df.isna().sum()
# Out:
# sku             0
# name            0
# desc            7
# price          45
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %%
# test_df.loc[test_df['desc'].isna(),'desc'] = test_df.loc[test_df['desc'].isna(), 'name']
test_df = test_df.dropna(subset='desc')

# %%
test_df = test_df.dropna(subset='price')

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10527 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10527 non-null  object
#  1   name         10527 non-null  object
#  2   desc         10527 non-null  object
#  3   price        10527 non-null  object
#  4   promo_price  10527 non-null  object
#  5   in_stock     10527 non-null  int64
#  6   type         10477 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 657.9+ KB

# %%
test_df.isnull().sum()
# Out:
# sku             0
# name            0
# desc            0
# price           0
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %% [markdown]
# Changing Datatypes:

# %%
test_df['price'] = pd.to_numeric(test_df['price'])

# %%
test_df['price'].str.count("\.").value_counts()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipython-input-3722692361.py:1: SyntaxWarning: invalid escape sequence '\.'
#   test_df['price'].str.count("\.").value_counts()
# price
# 1    6937
# 0    3214
# 2     376
# Name: count, dtype: int64

# %%
promo_price_corrupted = test_df.loc[(test_df['promo_price'].str.contains('\d+\.\d+\.\d+')) | (test_df['promo_price'].str.contains('\d+\.\d{3, }')), :].shape[0]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-2644527742.py:1: SyntaxWarning: invalid escape sequence '\d'
#   promo_price_corrupted = test_df.loc[(test_df['promo_price'].str.contains('\d+\.\d+\.\d+')) | (test_df['promo_price'].str.contains('\d+\.\d{3, }')), :].shape[0]
# /tmp/ipython-input-2644527742.py:1: SyntaxWarning: invalid escape sequence '\d'
#   promo_price_corrupted = test_df.loc[(test_df['promo_price'].str.contains('\d+\.\d+\.\d+')) | (test_df['promo_price'].str.contains('\d+\.\d{3, }')), :].shape[0]

# %%
(promo_price_corrupted/test_df.shape[0])*100
# Out:
# 43.64016338937969

# %%
test_df = test_df.drop(columns='promo_price')

# %%
test_df.sample(10)
# Out:
#              sku                                               name  \
# 13023    PAC1488  Samsung SSD 850 expansion kit EVO 250 GB to 21...
# 19121  ELA0021-A  Open - Elago Airpod Charging stand Charging St...
# 3147     JAW0042                   Jawbone UP3 Activity Monitor Red
# 2667     APP0701   Apple 45W MagSafe 2 charger MacBook Air in Ju...
# 13502    WAC0203                    Wacom Bamboo Stylus Duo 4 Black
# 1286     SPE0127   Candishell Speck iPhone 6 Case Black / Dark Gray
# 19130  TWS0035-A  Open - Twelve South HiRise for iMac & Cinema D...
# 12168    AP20101  Like new - Apple iPad mini Smart Cover 4 Blue ...
# 17427    AP20321                Like new - Apple iPhone 7 32GB Gold
# 16127  WIT0011-A  Open - Withings Blood Pressure Monitor Wireles...
#
#                                                     desc       price  \
# 13023  SSD upgrade kit 250GB for 215-inch iMac Late 2...      150.97
# 19121  Support Silicone refitted to install and charg...       19.95
# ...

# %%
price_corrupted = test_df.loc[(test_df['price'].astype(str).str.contains('\d+\.\d+\.\d+')) | (test_df['price'].astype(str).str.contains('\d+\.\d{3, }')), :]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-1689061708.py:1: SyntaxWarning: invalid escape sequence '\d'
#   price_corrupted = test_df.loc[(test_df['price'].astype(str).str.contains('\d+\.\d+\.\d+')) | (test_df['price'].astype(str).str.contains('\d+\.\d{3, }')), :]
# /tmp/ipython-input-1689061708.py:1: SyntaxWarning: invalid escape sequence '\d'
#   price_corrupted = test_df.loc[(test_df['price'].astype(str).str.contains('\d+\.\d+\.\d+')) | (test_df['price'].astype(str).str.contains('\d+\.\d{3, }')), :]

# %%
price_corrupted
# Out:
#              sku                                               name  \
# 665    CRU0015-2  Crucial memory Mac 16GB (2x8GB) SO-DIMM DDR3 1...
# 792      APP0672                    Apple iPhone 5S 16GB Space Gray
# 797      APP0673                        Apple iPhone 5S 16GB Silver
# 827      PAC0339             NewerTech miniStack 4TB Hard Drive Mac
# 885      PAC0376       OWC Mercury Elite Pro Dual Thunderbolt + 8TB
# ...          ...                                                ...
# 19312    REP0424                       Input repair Headphones iPad
# 19313    REP0421                     iPad charging connector repair
# 19314    REP0416                           iPad front camera repair
# 19315    REP0413                            repair rear camera iPad
# 19316    REP0407                                iPad battery repair
#
#                                                     desc      price  in_stock  \
# ...

# %%
test_df = test_df.drop(price_corrupted.index)

# %%
test_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price  in_stock  \
# 0           Aluminum support compatible with all MacBook  59.99         1
# ...

# %%
test_df['price'] = pd.to_numeric(test_df['price'])

# %%
mask = test_df['price'].apply(lambda x: np.round(x, 2) != x)

# Show the rows
price_corrupted = test_df[mask]
price_corrupted
# Out:
#              sku                                               name  \
# 362      REP0043                      Speaker lower repair iPhone 4
# 480      PIE0011                     Internal Battery for iPhone 3G
# 515      SEN0061  Sennheiser EZX 80 Handsfree iPhone iPad and iP...
# 518      SEV0026  Service installation RAM + HDD + SSD MacBook /...
# 525      SEV0024      Service installation RAM + HDD + SSD Mac mini
# ...          ...                                                ...
# 19162  FIB0002-A        Open - Fibaro HomeKitt Sensor Door / Window
# 19185    RIN0017                                    Chime Bell Ring
# 19259  TPL0030-A  Open - TP-Link TL-PA4010P Passthrough Powerlin...
# 19298    REP0428                      iPhone Speaker lower repair 7
# 19306    REP0429                 iPhone Speaker lower repair 7 plus
#
#                                                     desc    price  in_stock  \
# ...

# %% [markdown]
# Dropping 'price' with 3 numbers after decimal point

# %%
test_df = test_df[~mask]

# %%
test_df

# %%
test_df.sample(10)
# Out:
#              sku                                               name  \
# 16216    APP2216  Apple iMac 27 "Core i5 3.4GHz Retina 5K | 8GB ...
# 1199     APP0829                    Apple iPhone 6 Plus 16GB Silver
# 18783  TUC0312-A  Open - Tucano Minerale iPad Case 105 Pro "Rose...
# 13510    BEL0292  Belkin SheerForce Air Protect Case iPhone 6 / ...
# 18532    OWC0268   OWC Express External Enclosure 25 "USB 3.0 Plata
# 2481     UAG0020  Urban Armor Gear Scout Folio Case Cover iPhone...
# 18477    APP2708  Apple iMac Pro 27 "8-core Intel Xeon W 32GHz |...
# 2061     SEA0073  Seagate Backup Plus Slim External Hard Drive 2...
# 15002  SPE0174-A   Open - Speck SeeThru Case MacBook Air 11 "Yellow
# 1821     SPE0144  SmartShell Speck Case Macbook Air 13 "Hot Lips...
#
#                                                     desc    price  in_stock  \
# 16216  IMac desktop computer 27 inch 5K Retina 8GB RA...  2219.00         0
# ...

# %%
test_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price  in_stock  \
# 0           Aluminum support compatible with all MacBook  59.99         1
# ...

# %%
test_df.loc[test_df['price'] == 0]
# Out:
# Empty DataFrame
# Columns: [sku, name, desc, price, in_stock, type]
# Index: []

# %% [markdown]
# # Hesiting to delete huge amount of rows with two decimal points, trying to solve them

# %% [markdown]
# --Create a working copy of promo_price
#
# test_df['clean_promo_price'] = test_df['promo_price']
# test_df
#
# test_df.info()
#
# test_df['clean_promo_price'] = pd.to_numeric(test_df['clean_promo_price'], errors='coerce')
#
# test_df['clean_promo_price'].min()
#
# --Created a function to remove two decimal points
#
# def clean_price(value):
#     if pd.isna(value):
#         return np.nan
#     # Remove all dots except the last one
#     parts = value.split('.')
#     if len(parts) > 2:
#         # join everything except last part as thousand-sep
#         value = ''.join(parts[:-1]) + '.' + parts[-1]
#     # Replace comma with dot (European decimal to standard)
#     # value = value.replace(',', '.')
#     try:
#         return float(value)
#     except:
#         return np.nan
#
#
# --calling the function to make changes in clean_promo_price
#
# test_df['price_clean'] = test_df['price'].apply(clean_price)
# test_df['clean_promo_price'] = test_df['promo_price'].apply(clean_price)
#
#
# --Handle too many decimal places
# (more than 2 decimals is suspicious, so round safely to 2 decimals)
#
# test_df['clean_promo_price'] = test_df['clean_promo_price'].round(2)
#
# --Show all rows where price is null
# null_price_rows = test_df[test_df['price'].isna()]
#
# print(null_price_rows)
#
# --Or if you only want to see certain columns for proof
# print(null_price_rows[['sku', 'name', 'desc', 'price', 'promo_price']])
#
# test_df.loc[test_df['clean_promo_price'] > 1000]
#
# --Fix promo_price > price → replace with price (means no discount applied)
# changes still in clean_promo_price
#
# test_df.loc[test_df['promo_price'] > test_df['price'], 'clean_promo_price'] = test_df['price']
# test_df
#
# --Replaced clean_promo_price into original promo_price and dropped clean_promo_price
#
# test_df['promo_price'] = test_df['clean_promo_price']
#
# test_df = test_df.drop(columns='clean_promo_price', axis=1)

# %% [markdown]
# # Created % of discount column:
#
# test_df['discount_pct'] = ((test_df['price'] - test_df['promo_price']) / test_df['price']) * 100
# test_df
#
# test_df['discount_pct'] = test_df['discount_pct'].round(1)
#
# test_df['discount_pct'].describe()

# %% [markdown]
# Products with discounts:
#
# discounted_products = test_df.loc[test_df['discount_pct'] > 0]
# discounted_products
#
# Trying to find how many products fall into 25% and below, 50% and below, 75% and below, above 75%
#
# below_25 = discounted_products[discounted_products['discount_pct'] <= 25].shape[0]
# below_50 = discounted_products[(discounted_products['discount_pct'] > 25) & (discounted_products['discount_pct'] <= 50)].shape[0]
# below_75 = discounted_products[(discounted_products['discount_pct'] > 50) & (discounted_products['discount_pct'] <= 75)].shape[0]
# above_75 = discounted_products[discounted_products['discount_pct'] > 75].shape[0]
#
# summary = {
#     '≤25%': below_25,
#     '26–50%': below_50,
#     '51–75%': below_75,
#     '>75%': above_75
# }
#
# print(summary)
